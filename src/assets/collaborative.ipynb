# %% [markdown]
# COLLABORATIVE FILTERING

# %%
import pandas as pd

# %%
df_inter = pd.read_csv('article_recomendations.csv')
df_inter.head()
# Out:
#                                         If you liked  \
# 0  Chrome OS now has Material Design for the desktop
# 1  Eddy Cue and Craig Federighi Open Up About Lea...
# 2  Livraria dá adeus a estoque e imprime livros n...
# 3         Apple's new file manager, APFS, is awesome
# 4    Confirmed: Walmart buys Jet.com for $3B in cash
#
#                                     Recommendation 1  \
# 0  Progressive Web App - first introduced on Goog...
# 1  Google Cloud Platform's preemptible VMs are no...
# 2  Up your app's sharing game with DirectShare - ...
# 3                               The End Of Apple Man
# 4   A step-by-step guide to agile growth experiments
#
#                                     Recommendation 2  \
# 0                            Alecrim/AlecrimCoreData
# 1                                               Cubr
# 2  Google I/O 2016: Android's failure to innovate...
# 3  A New Number Format for Computers Could Nuke A...
# ...

# %%
df_inter = pd.read_csv('content_filtering_results.csv')
df_inter.head()
# Out:
#              contentId  6031953227014493100  -1676378465482420452  \
# 0  6031953227014493100             1.000000              0.007745
# 1 -1676378465482420452             0.007745              1.000000
# 2  8900292750226176660             0.008207              0.015900
# 3  8734156751308150579             0.000000              0.053310
# 4  6817244649248188271             0.060481              0.003958
#
#    8900292750226176660  8734156751308150579  6817244649248188271  \
# 0             0.008207             0.000000             0.060481
# 1             0.015900             0.053310             0.003958
# 2             1.000000             0.010786             0.001188
# 3             0.010786             1.000000             0.000000
# 4             0.001188             0.000000             1.000000
#
#    -7442296890640709658  -885886002174762919  -3231932874544830919  \
# 0              0.001540             0.000546              0.237176
# ...
